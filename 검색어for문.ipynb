# %%
import time

import warnings
warnings.filterwarnings('ignore')

# %%
from selenium import webdriver  # 동적크롤링
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

# %%
#리뷰 추출 함수 생성
def extract_review():
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 리뷰 추출
    rev = []  # 추출한 리뷰 저장
    for i in range(1, 11): # 더보기 누르지 않은 상태로 최대 10개
        try:  # 사진 없는 후기는 div 3번째에 텍스트 위치
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[7]/div[3]/div[4]/div[1]/ul/li['+str(i)+']/div[3]/a').send_keys(Keys.ENTER) # 텍스트 전체 볼 수 있게 클릭
            time.sleep(2)
            comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[7]/div[3]/div[4]/div[1]/ul/li['+str(i)+']/div[3]/a/span').text  # 리뷰
            rev.append(comment)
        except: # 사진 있는 후기는 div 4번째에 텍스트가 위치
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[7]/div[3]/div[4]/div[1]/ul/li['+str(i)+']/div[4]/a').send_keys(Keys.ENTER)
            time.sleep(2)
            comment = driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[7]/div[3]/div[4]/div[1]/ul/li['+str(i)+']/div[4]/a/span').text  # 리뷰
            rev.append(comment)
    return rev

# %%
data = []

# %%
df=pd.read_csv('제주음식점최종.csv')
df.head()
#도로명 주소 NAN때문에 전처리 다시 해줘야함 
#결측치 행 삭제
df.dropna(axis=0,inplace=True)
df
# Out:
#              사업장명 상세영업상태명                        소재지전체주소  \
# 0          탑동에이치지      영업        제주특별자치도 제주시 삼도이동 1120-2
# 1        에릭스에스프레소      영업   제주특별자치도 제주시 구좌읍 세화리 1397-6번지
# 2        일품순두부한림점      영업   제주특별자치도 제주시 한림읍 대림리 1845-2번지
# 3      김복남맥주제주아라점      영업          제주특별자치도 제주시 아라일동 6139
# 4           봉플라봉뱅      영업  제주특별자치도 제주시 연동 312-57번지 정인하우스
# ...           ...     ...                            ...
# 15788      돈가스스토리      영업         제주특별자치도 서귀포시 법환동 393-2
# 15789  과일사탕탕후루2호점      영업        제주특별자치도 서귀포시 서귀동 296-13
# 15790         영교집      영업      제주특별자치도 서귀포시 대정읍 보성리 2477
# 15791   황가네흑족발중문점      영업          제주특별자치도 서귀포시 중문동 2017
# 15792      야호중화포차      영업          제주특별자치도 서귀포시 중문동 2017
#
#                                        도로명전체주소  도로명우편번호   업종구분소분류        도  \
# 0              제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  63166.0        기타  제주특별자치도
# 1                   제주특별자치도 제주시 구좌읍 구좌로 77, 1층  63361.0        기타  제주특별자치도
# 2                 제주특별자치도 제주시 한림읍 한림상로 237, 1층  63030.0        한식  제주특별자치도
# 3           제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  63248.0  식육(숯불구이)  제주특별자치도
# 4          제주특별자치도 제주시 문송1길 6-1, 정인하우스 1층 (연동)  63122.0        기타  제주특별자치도
# ...                                        ...      ...       ...      ...
# 15788          제주특별자치도 서귀포시 이어도로 946, 1층 (법환동)  63573.0       경양식  제주특별자치도
# 15789            제주특별자치도 서귀포시 중앙로 65, 1층 (서귀동)  63592.0       중국식  제주특별자치도
# 15790     제주특별자치도 서귀포시 대정읍 글로벌에듀로 370, 1층 130호  63644.0        한식  제주특별자치도
# 15791  제주특별자치도 서귀포시 천제연로207번길 7, 2층 201호 (중문동)  63545.0        한식  제주특별자치도
# 15792  제주특별자치도 서귀포시 천제연로207번길 7, 가동 102호 (중문동)  63545.0       중국식  제주특별자치도
#
#           시          로
# 0       제주시      무근성안길
# 1       제주시        구좌읍
# 2       제주시        한림읍
# 3       제주시        중앙로
# 4       제주시       문송1길
# ...     ...        ...
# 15788  서귀포시       이어도로
# 15789  서귀포시        중앙로
# 15790  서귀포시        대정읍
# 15791  서귀포시  천제연로207번길
# 15792  서귀포시  천제연로207번길
#
# [15519 rows x 9 columns]

# %%
#도로명주소 슬라이싱 후 검색어 열 생성
df['검색어']=df['사업장명']+df['시']+df['로']

# %%
#5개만 임시로 실험해보기
df_temp=df[:5]
df_temp
# Out:
#          사업장명 상세영업상태명                        소재지전체주소  \
# 0      탑동에이치지      영업        제주특별자치도 제주시 삼도이동 1120-2
# 1    에릭스에스프레소      영업   제주특별자치도 제주시 구좌읍 세화리 1397-6번지
# 2    일품순두부한림점      영업   제주특별자치도 제주시 한림읍 대림리 1845-2번지
# 3  김복남맥주제주아라점      영업          제주특별자치도 제주시 아라일동 6139
# 4       봉플라봉뱅      영업  제주특별자치도 제주시 연동 312-57번지 정인하우스
#
#                                도로명전체주소  도로명우편번호   업종구분소분류        도    시  \
# 0      제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  63166.0        기타  제주특별자치도  제주시
# 1           제주특별자치도 제주시 구좌읍 구좌로 77, 1층  63361.0        기타  제주특별자치도  제주시
# 2         제주특별자치도 제주시 한림읍 한림상로 237, 1층  63030.0        한식  제주특별자치도  제주시
# 3   제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  63248.0  식육(숯불구이)  제주특별자치도  제주시
# 4  제주특별자치도 제주시 문송1길 6-1, 정인하우스 1층 (연동)  63122.0        기타  제주특별자치도  제주시
#
#        로               검색어
# 0  무근성안길    탑동에이치지제주시무근성안길
# 1    구좌읍    에릭스에스프레소제주시구좌읍
# 2    한림읍    일품순두부한림점제주시한림읍
# 3    중앙로  김복남맥주제주아라점제주시중앙로
# 4   문송1길      봉플라봉뱅제주시문송1길

# %%
# 크롬으로 리스트 검색어 돌리기 
driver = webdriver.Chrome(ChromeDriverManager().install())

for i in df_temp['검색어']:
    # 검색창에 입력하지 않고 직접 해당 숙소의 주소로 이동
    url ='https://map.naver.com/p/search/'+str(i)+'/place/1457625698?c=15.00,0,0,3,dh&isCorrectAnswer=true'
    driver.get(url)
    time.sleep(8)
